# %% [markdown]
# This notebook demonstrates Bayesian Hamiltonian and Liouvillian learning based on the Bayesian framework developed in Evans et al. Scalable Bayesian Hamiltonian learning. *arXiv:1912.07636* (2019).
#
# # TODO: add Bayesian Hamiltonian learning
