# %% [markdown]
# This notebook demonstrates Hamiltonian and Liouvillian learning from short time dynamics as demonstrated in Kraft et al. Bounded-Error Quantum Simulation via Hamiltonian and Lindbladian Learning. *arXiv:2511.23392* (2026).
#
# We are going to learn the Hamiltonian and dissipation rates of a mock experiment using different parametrizations.
#
# # TODO: fix learning method ``short-time-dynamics`` in ``hamiltonian_learning.py`` module
