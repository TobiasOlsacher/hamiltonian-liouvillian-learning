# %% [markdown]
# This notebook demonstrates how to use Hamiltonian and Liouvillian learning for bounded error quantum simulation as introduced in Kraft et al. Bounded-Error Quantum Simulation via Hamiltonian and Lindbladian Learning. *arXiv:2511.23392* (2026).
#
# We are going to first learn the Hamiltonian of a mock experiment and then bound the error of the quantum simulation from the errobars of the learned Hamiltonian.
#
# # TODO: add bounded-error quantum simulation
