# %% [markdown]
# This notebook demonstrates Hamiltonian and Liouvillian learning from short time dynamics as introduced in ``França et al. Efficient and robust estimation of many-qubit Hamiltonians (2024)``.
#
# We are going to learn the Hamiltonian and dissipation rates of a mock experiment using different parametrizations.
#
# # TODO: add learning from short-time dynamics
